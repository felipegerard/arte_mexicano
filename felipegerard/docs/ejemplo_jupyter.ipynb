# %% [markdown]
# ### Esto es un título

# %%
n <- 1000
x <- rnorm(n, 0, 1)
y <- rnorm(n, 0, 2)
plot(x,y)
# Out:
# plot without title

# %% [markdown]
# Para usar ggplot2 hay que pasarlos a pdf o png

# %%
library(ggplot2)
p <- qplot(x,y)
ggsave('imagenes/ejemplo.pdf', plot = p, width = 5, height = 5)

# %% [markdown]
# Y usar Markdown para generar la gráfica:
# ![jaja](imagenes/ejemplo.pdf)
